# %% [markdown]
# # Problem Statement
#
# The task is to combine transaction, demographic, and offer data to determine which demographic groups respond best to which offer type. Here, we are just concerned with the bogo offer, and we will assess the effectiveness of this offer and identify the customers who respond best to it, enabling us to target them effectively and reduce customer churn rate.

# %% [markdown]
# # Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# # Import data

# %%
starbucks_bogo_data = pd.read_csv('/content/df_trans_cust_bogo_succ_rate.csv')
starbucks_bogo_data.head()
# Out:
#                         customer_id gender   age  offer_received  \
# 0  0009655768c64bdeb2e877511632db8f      M  33.0               1
# 1  00116118485d4dfda04fdbaba9a87b5c    NaN   NaN               2
# 2  0011e0d4e6b944f998e987f904e8c1e5      O  40.0               1
# 3  0020c2b971eb4e9188eac86d93036a77      F  59.0               2
# 4  0020ccbbb6d84e358d3414a3ff76cffd      F  24.0               2
#
#    offer_viewed  offer_completed  offer_view_rate  offer_comp_rate  \
# 0             1                1            100.0            100.0
# 1             2                0            100.0              0.0
# 2             1                1            100.0            100.0
# 3             1                1             50.0             50.0
# 4             2                2            100.0            100.0
#
#    total_trans  amount_trans  rewards_earned  time_lapsed_succ   income  \
# 0          8.0        127.60             9.0               0.0  72000.0
# 1          NaN           NaN             NaN               NaN      NaN
# 2          5.0         79.46            13.0             270.0  57000.0
# 3          8.0        196.86            14.0              84.0  90000.0
# 4         12.0        154.05            13.0             102.0  60000.0
#
#    membership_days    income_range membership_range age_range
# 0           2205.0  (70000, 90000]     (2200, 2700]  (30, 35]
# 1              NaN             NaN              NaN       NaN
# 2           1942.0  (50000, 70000]     (1700, 2200]  (35, 40]
# 3           2618.0  (70000, 90000]     (2200, 2700]  (55, 60]
# 4           2366.0  (50000, 70000]     (2200, 2700]  (20, 25]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Check/Drop null values

# %%
# Check null values
starbucks_bogo_data.isnull().sum()
# Out:
# customer_id            0
# gender              1910
# age                 1910
# offer_received         0
# offer_viewed           0
# offer_completed        0
# offer_view_rate        0
# offer_comp_rate        0
# total_trans         1910
# amount_trans        1910
# rewards_earned      1910
# time_lapsed_succ    4802
# income              1910
# membership_days     1910
# income_range        1990
# membership_range    1910
# age_range           1912
# dtype: int64

# %%
# Drop null values
starbucks_bogo_data.dropna(inplace=True)
starbucks_bogo_data.head()
# Out:
#                         customer_id gender   age  offer_received  \
# 0  0009655768c64bdeb2e877511632db8f      M  33.0               1
# 2  0011e0d4e6b944f998e987f904e8c1e5      O  40.0               1
# 3  0020c2b971eb4e9188eac86d93036a77      F  59.0               2
# 4  0020ccbbb6d84e358d3414a3ff76cffd      F  24.0               2
# 5  004b041fbfe44859945daa2c7f79ee64      F  55.0               1
#
#    offer_viewed  offer_completed  offer_view_rate  offer_comp_rate  \
# 0             1                1            100.0            100.0
# 2             1                1            100.0            100.0
# 3             1                1             50.0             50.0
# 4             2                2            100.0            100.0
# 5             1                1            100.0            100.0
#
#    total_trans  amount_trans  rewards_earned  time_lapsed_succ   income  \
# 0          8.0        127.60             9.0               0.0  72000.0
# 2          5.0         79.46            13.0             270.0  57000.0
# 3          8.0        196.86            14.0              84.0  90000.0
# 4         12.0        154.05            13.0             102.0  60000.0
# 5          6.0        138.36             7.0             162.0  74000.0
#
#    membership_days    income_range membership_range age_range
# 0           2205.0  (70000, 90000]     (2200, 2700]  (30, 35]
# 2           1942.0  (50000, 70000]     (1700, 2200]  (35, 40]
# 3           2618.0  (70000, 90000]     (2200, 2700]  (55, 60]
# 4           2366.0  (50000, 70000]     (2200, 2700]  (20, 25]
# 5           1823.0  (70000, 90000]     (1700, 2200]  (50, 55]

# %% [markdown]
# ## Typecast columns

# %%
starbucks_bogo_data[['age', 'total_trans', 'rewards_earned', 'time_lapsed_succ', 'income']] = starbucks_bogo_data[['age', 'total_trans', 'rewards_earned', 'time_lapsed_succ', 'income']].astype(int)
starbucks_bogo_data.head()
# Out:
#                         customer_id gender  age  offer_received  offer_viewed  \
# 0  0009655768c64bdeb2e877511632db8f      M   33               1             1
# 2  0011e0d4e6b944f998e987f904e8c1e5      O   40               1             1
# 3  0020c2b971eb4e9188eac86d93036a77      F   59               2             1
# 4  0020ccbbb6d84e358d3414a3ff76cffd      F   24               2             2
# 5  004b041fbfe44859945daa2c7f79ee64      F   55               1             1
#
#    offer_completed  offer_view_rate  offer_comp_rate  total_trans  \
# 0                1            100.0            100.0            8
# 2                1            100.0            100.0            5
# 3                1             50.0             50.0            8
# 4                2            100.0            100.0           12
# 5                1            100.0            100.0            6
#
#    amount_trans  rewards_earned  time_lapsed_succ  income  membership_days  \
# 0        127.60               9                 0   72000           2205.0
# 2         79.46              13               270   57000           1942.0
# 3        196.86              14                84   90000           2618.0
# 4        154.05              13               102   60000           2366.0
# 5        138.36               7               162   74000           1823.0
#
#      income_range membership_range age_range
# 0  (70000, 90000]     (2200, 2700]  (30, 35]
# 2  (50000, 70000]     (1700, 2200]  (35, 40]
# 3  (70000, 90000]     (2200, 2700]  (55, 60]
# 4  (50000, 70000]     (2200, 2700]  (20, 25]
# 5  (70000, 90000]     (1700, 2200]  (50, 55]

# %% [markdown]
# ## Select features

# %%
X = starbucks_bogo_data[['gender', 'age', 'offer_view_rate', 'offer_comp_rate', 'total_trans', 'amount_trans', 'rewards_earned', 'time_lapsed_succ', 'income', 'membership_days']].values
X
# Out:
# array([['M', 33, 100.0, ..., 0, 72000, 2205.0],
#        ['O', 40, 100.0, ..., 270, 57000, 1942.0],
#        ['F', 59, 50.0, ..., 84, 90000, 2618.0],
#        ...,
#        ['M', 71, 66.67, ..., 0, 73000, 2012.0],
#        ['M', 34, 100.0, ..., 0, 34000, 2293.0],
#        ['F', 45, 100.0, ..., 78, 62000, 2352.0]], dtype=object)

# %% [markdown]
# ## Data encoding

# %%
# One-Hot encoding
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
X
# Out:
# array([[0.0, 1.0, 0.0, ..., 0, 72000, 2205.0],
#        [0.0, 0.0, 1.0, ..., 270, 57000, 1942.0],
#        [1.0, 0.0, 0.0, ..., 84, 90000, 2618.0],
#        ...,
#        [0.0, 1.0, 0.0, ..., 0, 73000, 2012.0],
#        [0.0, 1.0, 0.0, ..., 0, 34000, 2293.0],
#        [1.0, 0.0, 0.0, ..., 78, 62000, 2352.0]], dtype=object)

# %% [markdown]
# # Feature scaling

# %%
# Feature scaling
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-0.90487655,  0.93207068, -0.12213275, ..., -0.88686617,
#          0.17812063, -0.26170037],
#        [-0.90487655, -1.07288   ,  8.18781219, ...,  2.45360421,
#         -0.51460108, -0.89353536],
#        [ 1.10512312, -1.07288   , -0.12213275, ...,  0.15239128,
#          1.00938668,  0.73049678],
#        ...,
#        [-0.90487655,  0.93207068, -0.12213275, ..., -0.88686617,
#          0.22430208, -0.72536636],
#        [-0.90487655,  0.93207068, -0.12213275, ..., -0.88686617,
#         -1.57677437, -0.0502879 ],
#        [ 1.10512312, -1.07288   , -0.12213275, ...,  0.07815861,
#         -0.28369384,  0.09145455]])

# %% [markdown]
# # Train model

# %%
# K-means Clustering
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)
y_kmeans
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 1, 1, ..., 0, 0, 1], dtype=int32)

# %% [markdown]
# # Predict/Analyse offer success

# %%
starbucks_bogo_data['offer_success'] = y_kmeans
starbucks_bogo_data
# Out:
#                             customer_id gender  age  offer_received  \
# 0      0009655768c64bdeb2e877511632db8f      M   33               1
# 2      0011e0d4e6b944f998e987f904e8c1e5      O   40               1
# 3      0020c2b971eb4e9188eac86d93036a77      F   59               2
# 4      0020ccbbb6d84e358d3414a3ff76cffd      F   24               2
# 5      004b041fbfe44859945daa2c7f79ee64      F   55               1
# ...                                 ...    ...  ...             ...
# 14986  fff29fb549084123bd046dbc5ceb4faa      F   59               9
# 14987  fff3ba4757bd42088c044ca26d73817a      F   69               1
# 14988  fff7576017104bcc8677a8d63322b5e1      M   71               3
# 14990  fffad4f4828548d1b5583907f2e9906b      M   34               5
# 14991  ffff82501cea40309d5fdd7edcca4a07      F   45               1
#
#        offer_viewed  offer_completed  offer_view_rate  offer_comp_rate  \
# 0                 1                1           100.00           100.00
# 2                 1                1           100.00           100.00
# 3                 1                1            50.00            50.00
# 4                 2                2           100.00           100.00
# 5                 1                1           100.00           100.00
# ...             ...              ...              ...              ...
# 14986             7                9            77.78           100.00
# 14987             1                1           100.00           100.00
# 14988             2                1            66.67            33.33
# 14990             5                5           100.00           100.00
# 14991             1                1           100.00           100.00
#
#        total_trans  amount_trans  rewards_earned  time_lapsed_succ  income  \
# 0                8        127.60               9                 0   72000
# 2                5         79.46              13               270   57000
# 3                8        196.86              14                84   90000
# 4               12        154.05              13               102   60000
# 5                6        138.36               7               162   74000
# ...            ...           ...             ...               ...     ...
# 14986           11        291.47              47                 0   93000
# 14987           11        580.98               9                 0   83000
# 14988            6         29.94               9                 0   73000
# 14990           12         88.83              15                 0   34000
# 14991           15        226.07              18                78   62000
#
#        membership_days     income_range membership_range age_range  \
# 0               2205.0   (70000, 90000]     (2200, 2700]  (30, 35]
# 2               1942.0   (50000, 70000]     (1700, 2200]  (35, 40]
# 3               2618.0   (70000, 90000]     (2200, 2700]  (55, 60]
# 4               2366.0   (50000, 70000]     (2200, 2700]  (20, 25]
# 5               1823.0   (70000, 90000]     (1700, 2200]  (50, 55]
# ...                ...              ...              ...       ...
# 14986           2073.0  (90000, 110000]     (1700, 2200]  (55, 60]
# 14987           2784.0   (70000, 90000]     (2700, 3200]  (65, 70]
# 14988           2012.0   (70000, 90000]     (1700, 2200]  (70, 75]
# 14990           2293.0   (30000, 50000]     (2200, 2700]  (30, 35]
# 14991           2352.0   (50000, 70000]     (2200, 2700]  (40, 45]
#
#        offer_success
# 0                  0
# 2                  1
# 3                  1
# 4                  1
# 5                  1
# ...              ...
# 14986              1
# 14987              1
# 14988              0
# 14990              0
# 14991              1
#
# [10138 rows x 18 columns]

# %%
starbucks_bogo_data[['offer_success', 'gender', 'age', 'offer_view_rate', 'offer_comp_rate', 'total_trans', 'amount_trans', 'rewards_earned', 'time_lapsed_succ', 'income', 'membership_days']]
# Out:
#        offer_success gender  age  offer_view_rate  offer_comp_rate  \
# 0                  0      M   33           100.00           100.00
# 2                  1      O   40           100.00           100.00
# 3                  1      F   59            50.00            50.00
# 4                  1      F   24           100.00           100.00
# 5                  1      F   55           100.00           100.00
# ...              ...    ...  ...              ...              ...
# 14986              1      F   59            77.78           100.00
# 14987              1      F   69           100.00           100.00
# 14988              0      M   71            66.67            33.33
# 14990              0      M   34           100.00           100.00
# 14991              1      F   45           100.00           100.00
#
#        total_trans  amount_trans  rewards_earned  time_lapsed_succ  income  \
# 0                8        127.60               9                 0   72000
# 2                5         79.46              13               270   57000
# 3                8        196.86              14                84   90000
# 4               12        154.05              13               102   60000
# 5                6        138.36               7               162   74000
# ...            ...           ...             ...               ...     ...
# 14986           11        291.47              47                 0   93000
# 14987           11        580.98               9                 0   83000
# 14988            6         29.94               9                 0   73000
# 14990           12         88.83              15                 0   34000
# 14991           15        226.07              18                78   62000
#
#        membership_days
# 0               2205.0
# 2               1942.0
# 3               2618.0
# 4               2366.0
# 5               1823.0
# ...                ...
# 14986           2073.0
# 14987           2784.0
# 14988           2012.0
# 14990           2293.0
# 14991           2352.0
#
# [10138 rows x 11 columns]

# %% [markdown]
# # Data Analysis and Insights

# %%
starbucks_bogo_data[starbucks_bogo_data['offer_success'] == 1].describe()
# Out:
#                age  offer_received  offer_viewed  offer_completed  \
# count  4710.000000     4710.000000   4710.000000      4710.000000
# mean     57.878981        2.447346      2.057749         1.975372
# std      16.628088        1.738136      1.645105         1.819361
# min      18.000000        1.000000      0.000000         0.000000
# 25%      48.000000        1.000000      1.000000         1.000000
# 50%      58.000000        2.000000      2.000000         1.000000
# 75%      69.000000        3.000000      3.000000         2.000000
# max     100.000000       17.000000     17.000000        17.000000
#
#        offer_view_rate  offer_comp_rate  total_trans  amount_trans  \
# count      4710.000000      4710.000000   4710.00000   4710.000000
# mean         84.138679        77.740930      8.67431    159.439970
# std          29.096815        34.184765      4.70868    138.973318
# min           0.000000         0.000000      1.00000      8.900000
# 25%          71.430000        50.000000      5.00000     78.750000
# 50%         100.000000       100.000000      8.00000    133.300000
# 75%         100.000000       100.000000     12.00000    198.067500
# max         100.000000       100.000000     28.00000   1608.690000
#
#        rewards_earned  time_lapsed_succ         income  membership_days  \
# count     4710.000000       4710.000000    4710.000000       4710.00000
# mean        15.700212         67.889384   72666.878981       2284.87155
# std          8.340323         77.469031   22099.412127        367.66413
# min          2.000000          0.000000   31000.000000       1744.00000
# 25%         10.000000          6.000000   56000.000000       1992.00000
# 50%         15.000000         42.000000   72000.000000       2213.00000
# 75%         21.000000        102.000000   89000.000000       2546.00000
# max         50.000000        594.000000  120000.000000       3566.00000
#
#        offer_success
# count         4710.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %% [markdown]
# # Offer success rate

# %%
starbucks_bogo_data['offer_success'].value_counts()
# Out:
# 0    5428
# 1    4710
# Name: offer_success, dtype: int64

# %% [markdown]
# # Conclusions

# %% [markdown]
# **Insights**
#
# Customers actually viewed and completed the bogo offer successfully
#
# - **Age range** 48-70
# - **Offer received** 1-3
# - **Total transactions made** 5-12
# - **Total amount spent** 80-200 dollars
# - **Rewards earned** 10-21
# - **Time lapsed success** 6-100 hours, mostly round 60 hours
# - **Income** 55,000 - 90,000 dollars
# - **Membership** 2000 - 2500 days or 5.5 - 7 years
#
# So, now we have an idea which customers are completing the BOGO offer successfully and whom to engage properly. We need to send more bogo offers or think better business stategies for the customers not covering in the above mentioned ranges of attributes.
#
#
#
# **Bogo offer success rate**
#
# Currently, we have around 50% BOGO offer success rate as per data collected
